# %%
import pandas as pd

# %%
#loading the entire dataset
debate_df = pd.read_csv("debate.csv")
debate_df.head()
# Out:
#    Line   Speaker                                               Text  \
# 0     1      Holt  Good evening from Hofstra University in Hempst...
# 1     2  Audience                                         (APPLAUSE)
# 2     3   Clinton                               How are you, Donald?
# 3     4  Audience                                         (APPLAUSE)
# 4     5      Holt                                  Good luck to you.
#
#          Date
# 0  2016-09-26
# 1  2016-09-26
# 2  2016-09-26
# 3  2016-09-26
# 4  2016-09-26

# %%
debate_df.tail()
# Out:
#      Line Speaker                                               Text  \
# 707   357   Kaine    It is about our troops. It is about our troops.
# 708   358   Pence  I understand why you want to change -- I under...
# 709   359   Kaine  How can you support the troops if you won't pa...
# 710   360   Pence  I understand why you want to change the subjec...
# 711   361   Kaine  Do you think Donald Trump is smart to not pay ...
#
#            Date
# 707  2016-10-04
# 708  2016-10-04
# 709  2016-10-04
# 710  2016-10-04
# 711  2016-10-04

# %%
debate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 4 columns):
# Line       712 non-null int64
# Speaker    712 non-null object
# Text       712 non-null object
# Date       712 non-null object
# dtypes: int64(1), object(3)
# memory usage: 22.3+ KB

# %%
#unique speakers from dataset
debate_df['Speaker'].unique()
# Out:
# array(['Holt', 'Audience', 'Clinton', 'Trump', 'CANDIDATES', 'Quijano',
#        'Kaine', 'Pence'], dtype=object)

# %%
#separating data for hillary alone
hillary = debate_df[debate_df.Speaker == 'Clinton']
hillary
# Out:
#      Line  Speaker                                               Text  \
# 2       3  Clinton                               How are you, Donald?
# 7       8  Clinton  Well, thank you, Lester, and thanks to Hofstra...
# 8       9  Clinton  I also want to see more companies do profit-sh...
# 13     14  Clinton  Well, I think that trade is an important issue...
# 21     22  Clinton  Well, let's stop for a second and remember whe...
# 23     24  Clinton  Nine million people -- nine million people los...
# 25     26  Clinton                           I think science is real.
# 27     28  Clinton  And I think it's important that we grip this a...
# 30     31  Clinton                                  Well, actually...
# 32     33  Clinton  Well, actually, I have thought about this quit...
# 34     35  Clinton  And I have -- well, not quite that long. I thi...
# 37     38  Clinton         ... million new jobs, a balanced budget...
# 39     40  Clinton  Incomes went up for everybody. Manufacturing j...
# 42     43  Clinton               Well, I've been a senator, Donald...
# 44     45  Clinton            And I have been a secretary of state...
# 46     47  Clinton                           And I have done a lot...
# 48     49  Clinton   Well, that's your opinion. That is your opinion.
# 50     51  Clinton  Well, that is just not accurate. I was against...
# 54     55  Clinton                                                No.
# 56     57  Clinton  Well, Donald, I know you live in your own real...
# 58     59  Clinton  ... which I was not responsible for, I conclud...
# 60     61  Clinton                     ... before you even announced.
# 62     63  Clinton                     Look, there are differences...
# 64     65  Clinton                                       There are...
# 66     67  Clinton  There are different views about what's good fo...
# 68     69  Clinton                            But in -- oh, but I do.
# 70     71  Clinton  In fact, I have written a book about it. It's ...
# 74     75  Clinton                     ... or at an airport near you.
# 76     77  Clinton  But it's because I see this -- we need to have...
# 79     80  Clinton         That can't -- that can't be left to stand.
# ..    ...      ...                                                ...
# 200   201  Clinton  I think -- I think -- I think Donald just crit...
# 216   217  Clinton               Well, just listen to what you heard.
# 218   219  Clinton  And clearly, as Donald just admitted, he knew ...
# 223   224  Clinton  Well, I think cyber security, cyber warfare wi...
# 225   226  Clinton  ... tough, long game here. And one of the thin...
# 227   228  Clinton  ... have said that Donald is unfit to be the c...
# 232   233  Clinton  Well, I think there are a number of issues tha...
# 236   237  Clinton  Well, I hope the fact-checkers are turning up ...
# 238   239  Clinton     That is absolutely proved over and over again.
# 240   241  Clinton  He actually advocated for the actions we took ...
# 241   242  Clinton  But the larger point -- and he says this const...
# 246   247  Clinton                           Lester, we've covered...
# 248   249  Clinton                         We've covered this ground.
# 273   274  Clinton                                          Whew, OK.
# 275   276  Clinton  Let's talk about two important issues that wer...
# 277   278  Clinton  That is not the right temperament to be comman...
# 279   280  Clinton  ... of what we heard Donald say has been about...
# 281   282  Clinton                       ... have a good time, folks.
# 283   284  Clinton  And, in fact, his cavalier attitude about nucl...
# 285   286  Clinton  It's a good one, though. It well describes the...
# 297   298  Clinton  Well, let me -- let me start by saying, words ...
# 299   300  Clinton          ... to be given any opportunities at all.
# 315   316  Clinton  Well, as soon as he travels to 112 countries a...
# 322   323  Clinton                Well, one thing. One thing, Lester.
# 324   325  Clinton  You know, he tried to switch from looks to sta...
# 326   327  Clinton  .... women don't deserve equal pay unless they...
# 328   329  Clinton  And one of the worst things he said was about ...
# 330   331  Clinton                        Her name is Alicia Machado.
# 332   333  Clinton  And she has become a U.S. citizen, and you can...
# 344   345  Clinton  Well, I support our democracy. And sometimes y...
#
#            Date
# 2    2016-09-26
# 7    2016-09-26
# 8    2016-09-26
# 13   2016-09-26
# 21   2016-09-26
# 23   2016-09-26
# 25   2016-09-26
# 27   2016-09-26
# 30   2016-09-26
# 32   2016-09-26
# 34   2016-09-26
# 37   2016-09-26
# 39   2016-09-26
# 42   2016-09-26
# 44   2016-09-26
# 46   2016-09-26
# 48   2016-09-26
# 50   2016-09-26
# 54   2016-09-26
# 56   2016-09-26
# 58   2016-09-26
# 60   2016-09-26
# 62   2016-09-26
# 64   2016-09-26
# 66   2016-09-26
# 68   2016-09-26
# 70   2016-09-26
# 74   2016-09-26
# 76   2016-09-26
# 79   2016-09-26
# ..          ...
# 200  2016-09-26
# 216  2016-09-26
# 218  2016-09-26
# 223  2016-09-26
# 225  2016-09-26
# 227  2016-09-26
# 232  2016-09-26
# 236  2016-09-26
# 238  2016-09-26
# 240  2016-09-26
# 241  2016-09-26
# 246  2016-09-26
# 248  2016-09-26
# 273  2016-09-26
# 275  2016-09-26
# 277  2016-09-26
# 279  2016-09-26
# 281  2016-09-26
# 283  2016-09-26
# 285  2016-09-26
# 297  2016-09-26
# 299  2016-09-26
# 315  2016-09-26
# 322  2016-09-26
# 324  2016-09-26
# 326  2016-09-26
# 328  2016-09-26
# 330  2016-09-26
# 332  2016-09-26
# 339   340   Trump  ... extremely rough to Hillary, to her family,...
# 341   342   Trump  ... $200 million is spent, and I'm either winn...
# 346   347   Trump  The other day, we were deporting 800 people. A...
# 348   349   Trump  Look, here's the story. I want to make America...
#
#            Date
# 10   2016-09-26
# 11   2016-09-26
# 15   2016-09-26
# 17   2016-09-26
# 19   2016-09-26
# 22   2016-09-26
# 24   2016-09-26
# 26   2016-09-26
# 29   2016-09-26
# 31   2016-09-26
# 33   2016-09-26
# 35   2016-09-26
# 38   2016-09-26
# 41   2016-09-26
# 43   2016-09-26
# 45   2016-09-26
# 47   2016-09-26
# 49   2016-09-26
# 51   2016-09-26
# 53   2016-09-26
# 55   2016-09-26
# 57   2016-09-26
# 59   2016-09-26
# 61   2016-09-26
# 63   2016-09-26
# 65   2016-09-26
# 67   2016-09-26
# 69   2016-09-26
# 71   2016-09-26
# 77   2016-09-26
# ..          ...
# 276  2016-09-26
# 278  2016-09-26
# 280  2016-09-26
# 282  2016-09-26
# 284  2016-09-26
# 287  2016-09-26
# 289  2016-09-26
# 291  2016-09-26
# 293  2016-09-26
# 295  2016-09-26
# 301  2016-09-26
# 303  2016-09-26
# 305  2016-09-26
# 307  2016-09-26
# 309  2016-09-26
# 311  2016-09-26
# 313  2016-09-26
# 317  2016-09-26
# 319  2016-09-26
# 325  2016-09-26
# 327  2016-09-26
# 329  2016-09-26
# 331  2016-09-26
# 333  2016-09-26
# 334  2016-09-26
# 337  2016-09-26
# 339  2016-09-26
# 341  2016-09-26
# 346  2016-09-26
# 348  2016-09-26
#
# [131 rows x 4 columns]

# %%
#cross talk that occured between the candidates
cross_talk = debate_df[(debate_df.Speaker == 'CANDIDATES') & (debate_df.Date.str.match('2016-09-26')) ]
cross_talk
# Out:
#      Line     Speaker         Text        Date
# 36     37  CANDIDATES  (CROSSTALK)  2016-09-26
# 52     53  CANDIDATES  (CROSSTALK)  2016-09-26
# 72     73  CANDIDATES  (CROSSTALK)  2016-09-26
# 88     89  CANDIDATES  (CROSSTALK)  2016-09-26
# 117   118  CANDIDATES  (CROSSTALK)  2016-09-26
# 196   197  CANDIDATES  (CROSSTALK)  2016-09-26
# 206   207  CANDIDATES  (CROSSTALK)  2016-09-26
# 213   214  CANDIDATES  (CROSSTALK)  2016-09-26
# 224   225  CANDIDATES  (CROSSTALK)  2016-09-26

# %% [markdown]
# # Number of times Spoken by the speakers

# %%
print("No of times hillary spoke on something", hillary.shape[0])
print ("No of times Trump spoke on something ", trump.shape[0])
print ("No of times there was cross talk between both ", cross_talk.shape[0])
# Out:
# No of times hillary spoke on something 96
# No of times Trump spoke on something  131
# No of times there was cross talk between both  9

# %%
# Who spoke the most number of times? 

# %matplotlib inline

total = pd.concat([hillary,trump,cross_talk])
import seaborn as sns
sns.set(style="whitegrid")

sns.countplot(x="Speaker", data = total)

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

hillary['num_words'] = hillary.apply(lambda row : len([i for i in word_tokenize(sent.lower()) if i not in stop](row['Text'])), axis = 1)
trump['num_words'] = trump.apply(lambda row : len(tokenizer.tokenize(row['Text'])), axis = 1)
# Out:
# /home/ks/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ks/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
hillary.head()
# Out:
#     Line  Speaker                                               Text  \
# 2      3  Clinton                               How are you, Donald?
# 7      8  Clinton  Well, thank you, Lester, and thanks to Hofstra...
# 8      9  Clinton  I also want to see more companies do profit-sh...
# 13    14  Clinton  Well, I think that trade is an important issue...
# 21    22  Clinton  Well, let's stop for a second and remember whe...
#
#           Date  num_words
# 2   2016-09-26          4
# 7   2016-09-26        147
# 8   2016-09-26        199
# 13  2016-09-26        319
# 21  2016-09-26        105

# %%
trump.head()
# Out:
#     Line Speaker                                               Text  \
# 10    11   Trump  Thank you, Lester. Our jobs are fleeing the co...
# 11    12   Trump  We cannot let it happen. Under my plan, I'll b...
# 15    16   Trump  Well, for one thing -- and before we start on ...
# 17    18   Trump  Secretary Clinton and others, politicians, sho...
# 19    20   Trump  Well, the first thing you do is don't let the ...
#
#           Date  num_words
# 10  2016-09-26        301
# 11  2016-09-26         96
# 15  2016-09-26        294
# 17  2016-09-26         59
# 19  2016-09-26        168

# %% [markdown]
# # War of words in continuos time

# %%
# Number of words spoken by Hillary and trump in continuos time.


from matplotlib import pyplot as plt
plt.figure(figsize=(14,8))

hillary['num_words'].plot(legend=True,color="blue",kind='line')
trump['num_words'].plot(legend = True,color="red",kind='line')

# %% [markdown]
# # Who spoke the most ?

# %%
import matplotlib.pyplot as plt

tot_words = []
tot_words.append(hillary['num_words'].sum())
tot_words.append(trump['num_words'].sum())
labels = 'Hillary','Trump'
colors = ['blue', 'red']
explode = (0.1, 0)

plt.pie(tot_words, explode =explode,colors=colors, shadow=True, startangle=90, labels=labels, 
                         autopct='%.2f')
plt.legend(labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # What did they speak about ?

# %%
hillary_text = ' '.join(hillary['Text']).lower()
trump_text = ' '.join(trump['Text']).lower()

# %%
from nltk.corpus import stopwords
stop = list(stopwords.words('english'))
stop.extend(['would','well','us','know','going','look','think','said','say','get','many','one','years','want','like',
             'go','things','much','really','thing','way','tax','got','make','tell'])

# %%
trump_top_words = pd.Series([_ for _ in tokenizer.tokenize(trump_text.lower()) if _ not in stop]).value_counts()[:10]
trump_top_words
# Out:
# country      52
# people       35
# secretary    27
# clinton      23
# good         20
# companies    20
# jobs         18
# new          18
# money        17
# bad          16
# dtype: int64

# %%
hillary_top_words = pd.Series([_ for _ in tokenizer.tokenize(hillary_text.lower()) if _ not in stop]).value_counts()[:10]
hillary_top_words
# Out:
# people      33
# donald      30
# need        23
# lot         18
# good        17
# jobs        17
# country     16
# business    15
# work        15
# new         14
# dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.xticks(fontsize=20)  
trump_top_words.plot(kind='bar', stacked=True, color='red')

# %%
plt.figure(figsize=(14,8))
plt.xticks(fontsize=20) 
hillary_top_words.plot(kind='bar', stacked=True, color='blue')
